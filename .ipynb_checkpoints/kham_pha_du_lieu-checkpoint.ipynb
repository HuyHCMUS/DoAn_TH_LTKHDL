# %% [markdown]
# # Khám phá dữ liệu

# %% [markdown]
# notebook này thực hiện việc khám phá dữ liệu

# %% [markdown]
# ## Import các thư viện cần thiết

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Đọc file dữ liêu

# %% [markdown]
# Dữ liệu của chúng ta được lưu trong file 'Anime.csv'. Chúng ta sẽ đọc dữ liệu và lưu vào DataFrame `data_df`

# %%
data_df = pd.read_csv('Anime.csv')

# %% [markdown]
# Hiển thị 5 dòng đầu của dữ liệu để xem đọc đúng chưa

# %%
data_df.head(5)
# Out:
#       ID                             Title  \
# 0  16498                Shingeki no Kyojin
# 1   1535                        Death Note
# 2   5114  Fullmetal Alchemist: Brotherhood
# 3  30276                     One Punch Man
# 4  11757                  Sword Art Online
#
#                                             Synonyms  \
# 0                                           AoT, SnK
# 1                                                 DN
# 2  Hagane no Renkinjutsushi Fullmetal Alchemist, ...
# 3                  One Punch-Man, One-Punch Man, OPM
# 4                                         S.A.O, SAO
#
#                      Japanese                          English  \
# 0                       進撃の巨人                  Attack on Titan
# 1                       デスノート                       Death Note
# 2  鋼の錬金術師 FULLMETAL ALCHEMIST  Fullmetal Alchemist Brotherhood
# 3                      ワンパンマン                    One Punch Man
# ...

# %% [markdown]
# Vậy là phần đọc dữ liệu đã ok!

# %% [markdown]
# ## Dữ liệu có bao nhiêu dòng và bao nhiêu cột?

# %% [markdown]
# Đếm số dòng và số cột rồi sau đó lần lượt lưu vào 2 biến `num_rows` và `num_cols`

# %%
num_rows, num_cols = data_df.shape
print('Số dòng: ',num_rows)
print('Số cột: ', num_cols)
# Out:
# Số dòng:  21460
# Số cột:  28

# %% [markdown]
# ## Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Mỗi dòng thể hiện các thông tin khác nhau về một bộ anime, có vẻ như tất cả các dòng đều có ý nghĩa giống nhau, không có dòng nào mang ý nghĩa khác so với các dòng còn lại

# %% [markdown]
# ## Dữ liệu có các dòng bị lặp không?

# %% [markdown]
# Chúng ta sử dụng hàm 'duplicated' trong pandas để kiểm tra dòng đó có phải bị lặp trong DataFrame hay không. Nếu kết quả là dòng đó bị lặp sẽ trả về giá trị 1, ngược lại sẽ là 0. Kế tiếp chúng ta sử dùng hàm 'sum' để tính tất cả giá trị trả về của hàm 'duplicated'. Nếu kết quả > 0 thì chứng tỏ có tồn tại dòng bị lặp. Sau đó chúng ta lưu kết quả vào biến `is_duplicated_rows` với giá `True` khi tồn tại dòng dữ liệu bị lặp

# %%
is_duplicated_rows = data_df.duplicated().sum() > 0

if is_duplicated_rows:
    print('Dữ liệu có tồn tại dòng bị lặp')
else:
    print("Dữ liệu không tồn tại dòng bị lặp")
# Out:
# Dữ liệu không tồn tại dòng bị lặp

# %% [markdown]
# ### Mỗi cột có ý nghĩa gì?
#
# Để xem ý nghĩa của mỗi cột thì:
# - Dựa vào link dữ liệu mà nhóm chúng em sử dụng, Kaggle có cung cấp thêm thông tin cũng như ý nghĩa của các cột, từ đó chúng em lấy dữ liệu và lưu vào file "anime_col_meaning.csv"
# - Để biết được mỗi cột có ý nghĩa gì thì:
#     - Đọc file "anime_col_meaning.csv" và lưu vào DataFrame "col_meaning_df", trong đó cột "Column" làm cột index và cột "Description" làm giá trị.
#     - Hiển thị  DataFrame "col_meaning_df" ra để xem.
# - Sử dụng câu lệnh `pd.set_option` để các chuỗi mô tả không bị cắt.

# %%
data_df.columns
# Out:
# Index(['ID', 'Title', 'Synonyms', 'Japanese', 'English', 'Synopsis', 'Type',
#        'Episodes', 'Status', 'Start_Aired', 'End_Aired', 'Premiered',
#        'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source', 'Genres',
#        'Themes', 'Demographics', 'Duration_Minutes', 'Rating', 'Score',
#        'Scored_Users', 'Ranked', 'Popularity', 'Members', 'Favorites'],
#       dtype='object')

# %%
fname = 'anime_col_meaning.csv'
col_meaning_df = pd.read_csv(fname, usecols=['Column', 'Description']).set_index('Column') 
pd.set_option('display.max_colwidth', 0)
col_meaning_df
# Out:
#                                                                                         Description
# Column
# ID                ID anime at MyAnimeList.net
# Title             The original name of the anime
# Synonyms          The synonym name of the anime
# Japanese          The title of the anime in Japanese
# English           The title of the anime in English
# Synopsis          The overview of the anime
# Type              Anime type
# Episodes          Number of episodes in anime
# Status            The status of whether the anime has not, is currently, or has been aired
# Start_Aired       The date or year when the anime started airing
# End_Aired         The date or year when the anime ended airing
# Premiered         Season premiered
# Broadcast         Anime broadcast schedule
# Producers         List of producers
# Licensors         List of licensors
# Studios           List of studios
# Source            The source of the anime
# Genres            List of genres
# ...

# %% [markdown]
# ### Chọn và loại bỏ một số cột
#
# Nhóm chúng em bỏ đi cột "Japanese" chứa tên Tiếng Nhật, vì có nhiều giá trị thiếu, khá khó để đọc và đã có cột "Title" chứa tên gốc của phim.
# Các cột còn lại vẫn được giữ lại để sử dụng tiếp cho việc khám phá và phân tích.
#
# Tổng quan về các cột mà chúng em sử dụng bao gồm:
# - Cột index: ID
# - Tên gọi và tổng quan về phim: Title, Synonyms, English, Synopsis
# - Thông tin liên quan đến phát sóng phim: Type, Episodes, Status, Start_Aired, End_Aired, Premiered, Broadcast
# - Một số thông tin về nhà sản xuất: Producers, Licensors, Studios
# - Nguồn gốc, thể loại và các đặc tính khác của phim: Source, Genres, Themes, Demographics, Duration_Minutes
# - Các đánh giá và xếp hạng của phim: Rating, Score, Scored_Users, Ranked, Popularity, Members, Favorites

# %%
data_df.drop(['Japanese'], axis=1, inplace = True)
shape = data_df.shape
shape
# Out:
# (21460, 27)

# %% [markdown]
# ### Mỗi cột hiện đang có kiểu dữ liệu gì? Có cột nào có kiểu dữ liệu chưa phù hợp để có thể xử lý tiếp không?

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21460 entries, 0 to 21459
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                21460 non-null  int64
#  1   Title             21460 non-null  object
#  2   Synonyms          21460 non-null  object
#  3   English           21460 non-null  object
#  4   Synopsis          21460 non-null  object
#  5   Type              21460 non-null  object
#  6   Episodes          20913 non-null  float64
#  7   Status            21460 non-null  object
#  8   Start_Aired       21460 non-null  object
#  9   End_Aired         21460 non-null  object
#  10  Premiered         21460 non-null  object
#  11  Broadcast         21460 non-null  object
#  12  Producers         21460 non-null  object
#  13  Licensors         21460 non-null  object
#  14  Studios           21460 non-null  object
#  15  Source            21460 non-null  object
# ...

# %% [markdown]
# Chúng em tính kiểu dữ liệu (dtype) của mỗi cột trong DataFrame `data_df` và lưu kết quả vào Series `dtypes` (Series này có index là tên cột).

# %%
dtypes = data_df.dtypes
dtypes
# Out:
# ID                  int64
# Title               object
# Synonyms            object
# English             object
# Synopsis            object
# Type                object
# Episodes            float64
# Status              object
# Start_Aired         object
# End_Aired           object
# Premiered           object
# Broadcast           object
# Producers           object
# Licensors           object
# Studios             object
# Source              object
# Genres              object
# Themes              object
# Demographics        object
# Duration_Minutes    float64
# Rating              object
# Score               float64
# Scored_Users        float64
# Ranked              float64
# Popularity          int64
# Members             int64
# Favorites           int64
# dtype: object

# %% [markdown]
# Nhìn vào kết quả của series 'dtypes' chúng ta có thể thấy, cột "Start_Aired" và "End_Aired" nên có kiểu dữ liệu datetime, nhưng hiện tại đang có kiểu dữ liệu object. Chúng ta có thể xem thêm về các giá trị 2 cột này.

# %%
data_df['Start_Aired'].unique()
# Out:
# array(['Apr 7, 2013', 'Oct 4, 2006', 'Apr 5, 2009', ..., 'Aug 2013',
#        'Dec 24, 2013', 'May 12, 2018'], dtype=object)

# %%
data_df['End_Aired'].unique()
# Out:
# array(['Sep 29, 2013', 'Jun 27, 2007', 'Jul 4, 2010', ..., 'Oct 27, 2015',
#        'May 30, 2018', 'Nov 6, 2014'], dtype=object)

# %% [markdown]
# Để dễ dàng khám phá, phân tích cũng như trích xuất ngày, tháng, năm ở 2 cột này, chúng ta nên đưa 2 cột này về kiểu dữ liệu datetime.
# Thay vì 'Sep 29, 2013' thì chuyển thành '09/29/2013'

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng số, các giá trị được phân bố như thế nào?

# %% [markdown]
# Với các cột có kiểu dữ liệu số, sẽ tính:
# - Tỉ lệ % (từ 0 đến 100) các giá trị thiếu
# - Số lượng các giá trị khác nhau
# - Số lần xuất hiện của mỗi giá trị
# - Giá trị min
# - Giá trị lower quartile (phân vị 25)
# - Giá trị median (phân vị 50)
# - Giá trị upper quartile (phân vị 75)
# - Giá trị max
# - Giá trị trung bình
#
# Lưu kết quả vào DataFrame `stat_col_numeric`, trong đó:
# - Tên của các cột là tên của các cột số trong `data_df`
# - Tên của các dòng là: "missing_ratio", "num_differ_value", "value", "min", "lower_quartile", "median", "upper_quartile", "max", "mean"
#
# Để dễ nhìn, tất cả các giá trị đều làm tròn với 1 chữ số thập phân bằng phương thức `.round(1)`.

# %%
def stat_numeric_col(col):
    temp = []
    # missing_ratio
    temp.append(round((100 - (len(col.dropna()) / len(col) * 100)), 1))
    # num_differ_value
    num_value, times = np.unique(col, return_counts=True)
    temp.append(len(num_value))
    # times appear of each value
    temp.append(pd.Series(data = times, index = num_value))
    # min =  0; median = 50;  max = 100
    for i in range(0, 101, 25):
        temp.append(round(np.nanpercentile(col, i, axis = 0), 1))
    # mean
    temp.append(col.mean())
    return temp

# %% [markdown]
# - Đối với các cột số 'Episodes', 'Duration_Minutes', 'Score', 'Scored_Users', 'Ranked', 'Popularity', 'Members', 'Favorites' hiện tại đang có dạng dữ liệu gì?

# %%
element = ['Episodes', 'Duration_Minutes', 'Score', 'Scored_Users', 'Ranked', 'Popularity', 'Members', 'Favorites']
data_df[element].dtypes
# Out:
# Episodes            float64
# Duration_Minutes    float64
# Score               float64
# Scored_Users        float64
# Ranked              float64
# Popularity          int64
# Members             int64
# Favorites           int64
# dtype: object

# %% [markdown]
# - Tất cả đều có kiểu dữ liệu phù hợp để đưa vào tính toán

# %%
stat_col_numeric = pd.DataFrame(index = ['missing_ratio', 'num_differ_value', 'value', 'min', 'lower_quartile', 'median', 'upper_quartile', 'max', 'mean'])

for i in element:
    stat_col_numeric[i] = stat_numeric_col(data_df[i])
stat_col_numeric
# Out:
#                                                                                                                                                                                                                    Episodes  \
# missing_ratio     2.5
# num_differ_value  231
# value             1.0       10140
# 2.0       1480
# 3.0       683
# 4.0       527
# 5.0       205
#          ...
# 1664.0    1
# 1787.0    1
# 1818.0    1
# 3057.0    1
# NaN       547
# Length: 231, dtype: int64
# min               1.0
# lower_quartile    1.0
# median            2.0
# upper_quartile    12.0
# max               3057.0
# mean              13.272892
#
#                                                                                                                                                                                      Duration_Minutes  \
# missing_ratio     2.8
# num_differ_value  153
# value             1.0      842
# 2.0      1320
# 3.0      1299
# 4.0      1027
# 5.0      962
# ...

# %% [markdown]
# ## Nhận xét:
# - Các cột "Episodes", "Scored_Users", "Popularity", "Members", "Favorites" dữ liệu tập trung chủ yếu ở giá trị thấp, chênh lệch rất lớn giữa min và max (từ 3000 đến 100000 lần) nên nhìn chung giá trị trung bình chênh lệch cũng không quá cao với min.
# - Cột "Duration", "Minutes" có dữ liệu không chênh lệch nhiều, các giá trị tập trung chủ yếu ở 50 - 75%.
# - Cột "Ranked", "Score" có dữ liệu phân bố đồng đều hơn ở các khoảng.

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng phân loại (categorical), các giá trị được phân bố như thế nào?

# %% [markdown]
# Xem tất cả các cột của dataframe:

# %%
data_df.columns
# Out:
# Index(['ID', 'Title', 'Synonyms', 'English', 'Synopsis', 'Type', 'Episodes',
#        'Status', 'Start_Aired', 'End_Aired', 'Premiered', 'Broadcast',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Genres', 'Themes',
#        'Demographics', 'Duration_Minutes', 'Rating', 'Score', 'Scored_Users',
#        'Ranked', 'Popularity', 'Members', 'Favorites'],
#       dtype='object')

# %% [markdown]
# Các cột không phải số là:

# %%
cat_cols =  data_df.select_dtypes(include='object')
#cat_cols

# %% [markdown]
# Các cột trên được chia thành 2 loại:
# - Các cột mà dữ liệu là 1 chuỗi đơn lẻ và chứa 1 thông tin
# - Các cột multidata, là những cột gồm nhiều thông tin được phân cách bởi dấu phẩy
#
# Trước hết, ta cần chia các cột có dấu phẩy đó thành kiểu list để dễ xử lý. Các cột multidata là:

# %%
multidata_cols = ['Producers', 'Studios', 'Genres', 'Themes', 'Demographics']

# %%
#Chuyển các cột multidata sang list
for col in multidata_cols:
    cat_cols[col] =  cat_cols[col].str.split(',')
#cat_cols

# %% [markdown]
# Những yếu tố cần xét của mỗi cột để khám phá sự phân bố của dữ liệu:
# - Phần trăm các giá trị bị thiếu
# - Số lượng các giá trị khác nhau (không kể các giá trị thiếu). Đối với các cột multidata, các giá trị khác nhau được tính là các giá trị trong list chứ không phải nguyên cả list.
# - Với mỗi giá trị khác nhau đó, tính phần trăm của nó. (Được tính bằng số lần xuất hiện của giá trị đó chia cho số dòng trong dataframe, không kể dòng mang giá trị thiếu)

# %% [markdown]
# Phần trăm giá trị bị thiếu

# %%
num_row = cat_cols.shape[0]
#Phẩn trăm giá trị bị thiếu
missing_ratio = np.sum(cat_cols.isna(), axis = 0) / num_row * 100

# %% [markdown]
# Số lượng các giá trị khác nhau và tỷ lệ của nó

# %%
#Các cột không phải multidata
cat_no_multi = [col for col in cat_cols.columns if col not in multidata_cols] 
num_diff_value = dict()
percent_diff_value = dict()
for col in cat_no_multi:
    num_not_na = len(cat_cols[col].dropna())
    #Tính số lượng các giá trị khác nhau
    num_diff_value[col] = len(set(cat_cols[col].dropna()))
    #Tính phần trăm của các giá trị khác nhau
    percent_diff_value[col] = (cat_cols.dropna(subset = [col]).groupby(col).size() / num_not_na * 100)
    #Sắp xếp phần trăm các giá trị khác nhau theo thứ tự giảm dần
    percent_diff_value[col] = percent_diff_value[col].sort_values(ascending=False)
    percent_diff_value[col] = percent_diff_value[col].round(3).to_dict()

# %%
#Các cột là multidata
for col in multidata_cols:
    num_not_na = len(cat_cols[col].dropna())
    #Tính số lượng các giá trị khác nhau
    num_diff_value[col] = len(set(cat_cols[col].dropna().explode()))
    #Tính phần trăm của các giá trị khác nhau
    percent_diff_value[col] = (cat_cols.dropna(subset = [col]).explode(col).groupby(col).size() / num_not_na * 100)
    #Sắp xếp phần trăm các giá trị khác nhau theo thứ tự giảm dần
    percent_diff_value[col] = percent_diff_value[col].sort_values(ascending=False)
    percent_diff_value[col] = percent_diff_value[col].round(3).to_dict()

# %%
pd.set_option('display.max_colwidth', 0)
num_diff_value = pd.Series(data = num_diff_value)
percent_diff_value = pd.Series(data = percent_diff_value)

cate_col_profiles_df = pd.DataFrame([missing_ratio, num_diff_value, percent_diff_value],  
                                    index = ["missing_ratio", "num_different_values", "percent_different_values"])
cate_col_profiles_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# Xem một số giá trị của mỗi cột mà có tỷ lệ lớn nhất

# %%
cate_col_profiles_df.loc['percent_different_values', : ]
# Out:
# Title           {'.hack//G.U. Returner': 0.005, 'Pittarazu Gekijou Manner CM': 0.005, 'Pittanko!! Nekozakana (2020)': 0.005, 'Pittanko!! Nekozakana': 0.005, 'Pittanko! Taiyou-sensei to Pittanko': 0.005, 'Pittanko! Nekozakana': 0.005, 'Pita Ten': 0.005, 'PistStar': 0.005, 'Piroppo': 0.005, 'Piplup Step': 0.005, 'Pipi Tobenai Hotaru': 0.005, 'Pinocchio yori Piccolino no Bouken': 0.005, 'Pinky Wakuwaku Tabi Stroll': 0.005, 'Pinky Street': 0.005, 'Pinky Monkey x FaFa Collaboration Animation: At Afternoon of Sunny Day': 0.005, 'Pinky Monkey no Umareta Hi': 0.005, 'Pinky': 0.005, 'Pinko no Hiden Curry': 0.005, 'Pinkerton': 0.005, 'Pittarazu': 0.005, 'Piyo no Ongaeshi': 0.005, 'Pink Mizu Dorobou Ame Dorobou': 0.005, 'Piyoko ni Omakase pyo!': 0.005, 'Platinum End': 0.005, 'Plastic Neesan': 0.005, 'Plastic Memories': 0.005, 'Plastic Little': 0.005, 'Planzet': 0.005, 'Planetes Picture Drama': 0.005, 'Planetes': 0.005, 'Planetarium Pokemon: Aurora kara no Message': 0.005, 'Planetarium Kamiusagi
# ...
